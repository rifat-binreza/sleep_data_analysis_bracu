# %%
import pandas as pd 
df=pd.read_csv("Sleep_health_and_lifestyle_dataset (1).csv")
df = df.dropna(subset=['Sleep Disorder']).copy()
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# 1         125/80          75        10000            NaN
# 2         125/80          75        10000            NaN
# 3         140/90          85         3000    Sleep Apnea
# 4         140/90          85         3000    Sleep Apnea

# %%
! pip install pycaret
# Out:
# Requirement already satisfied: pycaret in .\.venv\Lib\site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in .\.venv\Lib\site-packages (from pycaret) (9.9.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in .\.venv\Lib\site-packages (from pycaret) (8.1.8)
# Requirement already satisfied: tqdm>=4.62.0 in .\.venv\Lib\site-packages (from pycaret) (4.67.2)
# Requirement already satisfied: numpy<1.27,>=1.21 in .\.venv\Lib\site-packages (from pycaret) (1.26.4)
# Requirement already satisfied: pandas<2.2.0 in .\.venv\Lib\site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in .\.venv\Lib\site-packages (from pycaret) (3.1.6)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in .\.venv\Lib\site-packages (from pycaret) (1.11.4)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in .\.venv\Lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in .\.venv\Lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in .\.venv\Lib\site-packages (from pycaret) (2.0.6)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in .\.venv\Lib\site-packages (from pycaret) (0.14.1)
# Requirement already satisfied: category-encoders>=2.4.0 in .\.venv\Lib\site-packages (from pycaret) (2.7.0)
# Requirement already satisfied: lightgbm>=3.0.0 in .\.venv\Lib\site-packages (from pycaret) (4.6.0)
# Requirement already satisfied: numba>=0.55.0 in .\.venv\Lib\site-packages (from pycaret) (0.63.1)
# Requirement already satisfied: requests>=2.27.1 in .\.venv\Lib\site-packages (from pycaret) (2.32.5)
# Requirement already satisfied: psutil>=5.9.0 in .\.venv\Lib\site-packages (from pycaret) (7.2.2)
# Requirement already satisfied: markupsafe>=2.0.1 in .\.venv\Lib\site-packages (from pycaret) (3.0.3)
# Requirement already satisfied: importlib-metadata>=4.12.0 in .\.venv\Lib\site-packages (from pycaret) (8.7.1)
# Requirement already satisfied: nbformat>=4.2.0 in .\.venv\Lib\site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: cloudpickle in .\.venv\Lib\site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: deprecation>=2.1.0 in .\.venv\Lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in .\.venv\Lib\site-packages (from pycaret) (3.6.0)
# Requirement already satisfied: matplotlib<3.8.0 in .\.venv\Lib\site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: scikit-plot>=0.3.7 in .\.venv\Lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in .\.venv\Lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in .\.venv\Lib\site-packages (from pycaret) (6.5.2)
# Requirement already satisfied: kaleido>=0.2.1 in .\.venv\Lib\site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: schemdraw==0.15 in .\.venv\Lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in .\.venv\Lib\site-packages (from pycaret) (0.11.0)
# Requirement already satisfied: statsmodels>=0.12.1 in .\.venv\Lib\site-packages (from pycaret) (0.14.6)
# Requirement already satisfied: sktime==0.26.0 in .\.venv\Lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in .\.venv\Lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in .\.venv\Lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: packaging in .\.venv\Lib\site-packages (from sktime==0.26.0->pycaret) (26.0)
# Requirement already satisfied: scikit-base<0.8.0 in .\.venv\Lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: contourpy>=1.0.1 in .\.venv\Lib\site-packages (from matplotlib<3.8.0->pycaret) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\.venv\Lib\site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\.venv\Lib\site-packages (from matplotlib<3.8.0->pycaret) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in .\.venv\Lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.9)
# Requirement already satisfied: pillow>=6.2.0 in .\.venv\Lib\site-packages (from matplotlib<3.8.0->pycaret) (12.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in .\.venv\Lib\site-packages (from matplotlib<3.8.0->pycaret) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\.venv\Lib\site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\.venv\Lib\site-packages (from pandas<2.2.0->pycaret) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in .\.venv\Lib\site-packages (from pandas<2.2.0->pycaret) (2025.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in .\.venv\Lib\site-packages (from scikit-learn>1.4.0->pycaret) (3.6.0)
# Requirement already satisfied: patsy>=0.5.1 in .\.venv\Lib\site-packages (from category-encoders>=2.4.0->pycaret) (1.0.2)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in .\.venv\Lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (0.1.5)
# Requirement already satisfied: zipp>=3.20 in .\.venv\Lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.23.0)
# Requirement already satisfied: colorama>=0.4.4 in .\.venv\Lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in .\.venv\Lib\site-packages (from ipython>=5.5.0->pycaret) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in .\.venv\Lib\site-packages (from ipython>=5.5.0->pycaret) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in .\.venv\Lib\site-packages (from ipython>=5.5.0->pycaret) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in .\.venv\Lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in .\.venv\Lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in .\.venv\Lib\site-packages (from ipython>=5.5.0->pycaret) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in .\.venv\Lib\site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in .\.venv\Lib\site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in .\.venv\Lib\site-packages (from ipython>=5.5.0->pycaret) (4.15.0)
# Requirement already satisfied: wcwidth in .\.venv\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.5.3)
# Requirement already satisfied: comm>=0.1.3 in .\.venv\Lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in .\.venv\Lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in .\.venv\Lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.16)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in .\.venv\Lib\site-packages (from jedi>=0.18.1->ipython>=5.5.0->pycaret) (0.8.5)
# Requirement already satisfied: choreographer>=1.1.1 in .\.venv\Lib\site-packages (from kaleido>=0.2.1->pycaret) (1.2.1)
# Requirement already satisfied: logistro>=1.0.8 in .\.venv\Lib\site-packages (from kaleido>=0.2.1->pycaret) (2.0.1)
# Requirement already satisfied: orjson>=3.10.15 in .\.venv\Lib\site-packages (from kaleido>=0.2.1->pycaret) (3.11.6)
# Requirement already satisfied: pytest-timeout>=2.4.0 in .\.venv\Lib\site-packages (from kaleido>=0.2.1->pycaret) (2.4.0)
# Requirement already satisfied: simplejson>=3.19.3 in .\.venv\Lib\site-packages (from choreographer>=1.1.1->kaleido>=0.2.1->pycaret) (3.20.2)
# Requirement already satisfied: fastjsonschema>=2.15 in .\.venv\Lib\site-packages (from nbformat>=4.2.0->pycaret) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in .\.venv\Lib\site-packages (from nbformat>=4.2.0->pycaret) (4.26.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in .\.venv\Lib\site-packages (from nbformat>=4.2.0->pycaret) (5.9.1)
# Requirement already satisfied: attrs>=22.2.0 in .\.venv\Lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in .\.venv\Lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in .\.venv\Lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in .\.venv\Lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in .\.venv\Lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.5.1)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in .\.venv\Lib\site-packages (from numba>=0.55.0->pycaret) (0.46.0)
# Requirement already satisfied: narwhals>=1.15.1 in .\.venv\Lib\site-packages (from plotly>=5.14.0->pycaret) (2.15.0)
# Requirement already satisfied: dash>=2.11.0 in .\.venv\Lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.4.0)
# Requirement already satisfied: tsdownsample>=0.1.3 in .\.venv\Lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.4.1)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in .\.venv\Lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in .\.venv\Lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.1.5)
# Requirement already satisfied: retrying in .\.venv\Lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.4.2)
# Requirement already satisfied: nest-asyncio in .\.venv\Lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: setuptools in .\.venv\Lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (79.0.1)
# Requirement already satisfied: blinker>=1.9.0 in .\.venv\Lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in .\.venv\Lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.3.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in .\.venv\Lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in .\.venv\Lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.2.4)
# Requirement already satisfied: urllib3 in .\.venv\Lib\site-packages (from pmdarima>=2.0.4->pycaret) (2.6.3)
# Requirement already satisfied: pytest>=7.0.0 in .\.venv\Lib\site-packages (from pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (9.0.2)
# Requirement already satisfied: iniconfig>=1.0.1 in .\.venv\Lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in .\.venv\Lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (1.6.0)
# Requirement already satisfied: six>=1.5 in .\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib<3.8.0->pycaret) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.venv\Lib\site-packages (from requests>=2.27.1->pycaret) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in .\.venv\Lib\site-packages (from requests>=2.27.1->pycaret) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in .\.venv\Lib\site-packages (from requests>=2.27.1->pycaret) (2026.1.4)
# Requirement already satisfied: executing>=1.2.0 in .\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.5.0->pycaret) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in .\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.5.0->pycaret) (3.0.1)
# Requirement already satisfied: pure-eval in .\.venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=5.5.0->pycaret) (0.2.3)

# %%
df['Sleep Disorder'] = df['Sleep Disorder'].fillna('None')

# %%
from pycaret.classification import *
clf=setup(
       data=df,target='Sleep Disorder',session_id=12
)
# Out:
# <style type="text/css">
# #T_d69a4_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d69a4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d69a4_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d69a4_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d69a4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d69a4_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d69a4_row0_col1" class="data row0 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d69a4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d69a4_row1_col1" class="data row1 col1" >Sleep Disorder</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d69a4_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_d69a4_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d69a4_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_d69a4_row3_col1" class="data row3 col1" >Insomnia: 0, None: 1, Sleep Apnea: 2</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d69a4_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_d69a4_row4_col1" class="data row4 col1" >(374, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d69a4_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_d69a4_row5_col1" class="data row5 col1" >(374, 45)</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d69a4_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_d69a4_row6_col1" class="data row6 col1" >(261, 45)</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d69a4_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_d69a4_row7_col1" class="data row7 col1" >(113, 45)</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d69a4_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_d69a4_row8_col1" class="data row8 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d69a4_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_d69a4_row9_col1" class="data row9 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d69a4_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_d69a4_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d69a4_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_d69a4_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d69a4_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_d69a4_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d69a4_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_d69a4_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d69a4_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_d69a4_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d69a4_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_d69a4_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d69a4_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_d69a4_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d69a4_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_d69a4_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d69a4_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_d69a4_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d69a4_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_d69a4_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d69a4_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_d69a4_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d69a4_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_d69a4_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d69a4_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d69a4_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_d69a4_row22_col1" class="data row22 col1" >f70e</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .           23:08:55
# Status     . . . . . . . . . . . . . . . . . .  Loading Estimator
# Estimator  . . . . . . . . . . . . . . . . . .  Compiling Library
# <style type="text/css">
# #T_98b01 th {
#   text-align: left;
# }
# #T_98b01_row0_col0, #T_98b01_row1_col0, #T_98b01_row1_col1, #T_98b01_row1_col2, #T_98b01_row1_col3, #T_98b01_row1_col4, #T_98b01_row1_col5, #T_98b01_row1_col6, #T_98b01_row1_col7, #T_98b01_row2_col0, #T_98b01_row2_col1, #T_98b01_row2_col2, #T_98b01_row2_col3, #T_98b01_row2_col4, #T_98b01_row2_col5, #T_98b01_row2_col6, #T_98b01_row2_col7, #T_98b01_row3_col0, #T_98b01_row3_col1, #T_98b01_row3_col2, #T_98b01_row3_col3, #T_98b01_row3_col4, #T_98b01_row3_col5, #T_98b01_row3_col6, #T_98b01_row3_col7, #T_98b01_row4_col0, #T_98b01_row4_col1, #T_98b01_row4_col2, #T_98b01_row4_col3, #T_98b01_row4_col4, #T_98b01_row4_col5, #T_98b01_row4_col6, #T_98b01_row4_col7, #T_98b01_row5_col0, #T_98b01_row5_col1, #T_98b01_row5_col2, #T_98b01_row5_col3, #T_98b01_row5_col4, #T_98b01_row5_col5, #T_98b01_row5_col6, #T_98b01_row5_col7, #T_98b01_row6_col0, #T_98b01_row6_col1, #T_98b01_row6_col2, #T_98b01_row6_col3, #T_98b01_row6_col4, #T_98b01_row6_col5, #T_98b01_row6_col6, #T_98b01_row6_col7, #T_98b01_row7_col0, #T_98b01_row7_col1, #T_98b01_row7_col2, #T_98b01_row7_col3, #T_98b01_row7_col4, #T_98b01_row7_col5, #T_98b01_row7_col6, #T_98b01_row7_col7, #T_98b01_row8_col0, #T_98b01_row8_col1, #T_98b01_row8_col2, #T_98b01_row8_col3, #T_98b01_row8_col4, #T_98b01_row8_col5, #T_98b01_row8_col6, #T_98b01_row8_col7, #T_98b01_row9_col0, #T_98b01_row9_col1, #T_98b01_row9_col2, #T_98b01_row9_col3, #T_98b01_row9_col4, #T_98b01_row9_col5, #T_98b01_row9_col6, #T_98b01_row9_col7, #T_98b01_row10_col0, #T_98b01_row10_col1, #T_98b01_row10_col2, #T_98b01_row10_col3, #T_98b01_row10_col4, #T_98b01_row10_col5, #T_98b01_row10_col6, #T_98b01_row10_col7, #T_98b01_row11_col0, #T_98b01_row11_col1, #T_98b01_row11_col2, #T_98b01_row11_col3, #T_98b01_row11_col4, #T_98b01_row11_col5, #T_98b01_row11_col6, #T_98b01_row11_col7, #T_98b01_row12_col0, #T_98b01_row12_col1, #T_98b01_row12_col2, #T_98b01_row12_col3, #T_98b01_row12_col4, #T_98b01_row12_col5, #T_98b01_row12_col6, #T_98b01_row12_col7, #T_98b01_row13_col0, #T_98b01_row13_col1, #T_98b01_row13_col2, #T_98b01_row13_col3, #T_98b01_row13_col4, #T_98b01_row13_col5, #T_98b01_row13_col6, #T_98b01_row13_col7 {
#   text-align: left;
# }
# #T_98b01_row0_col1, #T_98b01_row0_col2, #T_98b01_row0_col3, #T_98b01_row0_col4, #T_98b01_row0_col5, #T_98b01_row0_col6, #T_98b01_row0_col7 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_98b01_row0_col8, #T_98b01_row1_col8, #T_98b01_row2_col8, #T_98b01_row3_col8, #T_98b01_row4_col8, #T_98b01_row5_col8, #T_98b01_row6_col8, #T_98b01_row7_col8, #T_98b01_row8_col8, #T_98b01_row9_col8, #T_98b01_row10_col8, #T_98b01_row11_col8, #T_98b01_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_98b01_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_98b01">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98b01_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_98b01_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_98b01_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_98b01_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_98b01_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_98b01_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_98b01_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_98b01_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_98b01_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98b01_level0_row0" class="row_heading level0 row0" >nb</th>
#       <td id="T_98b01_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_98b01_row0_col1" class="data row0 col1" >0.9160</td>
#       <td id="T_98b01_row0_col2" class="data row0 col2" >0.9448</td>
#       <td id="T_98b01_row0_col3" class="data row0 col3" >0.9160</td>
#       <td id="T_98b01_row0_col4" class="data row0 col4" >0.9211</td>
#       <td id="T_98b01_row0_col5" class="data row0 col5" >0.9143</td>
#       <td id="T_98b01_row0_col6" class="data row0 col6" >0.8524</td>
#       <td id="T_98b01_row0_col7" class="data row0 col7" >0.8557</td>
#       <td id="T_98b01_row0_col8" class="data row0 col8" >0.0330</td>
#     </tr>
#     <tr>
#       <th id="T_98b01_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_98b01_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_98b01_row1_col1" class="data row1 col1" >0.9121</td>
#       <td id="T_98b01_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_98b01_row1_col3" class="data row1 col3" >0.9121</td>
#       <td id="T_98b01_row1_col4" class="data row1 col4" >0.9195</td>
#       <td id="T_98b01_row1_col5" class="data row1 col5" >0.9096</td>
#       <td id="T_98b01_row1_col6" class="data row1 col6" >0.8449</td>
#       <td id="T_98b01_row1_col7" class="data row1 col7" >0.8490</td>
#       <td id="T_98b01_row1_col8" class="data row1 col8" >0.0220</td>
#     </tr>
#     <tr>
#       <th id="T_98b01_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_98b01_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_98b01_row2_col1" class="data row2 col1" >0.9081</td>
#       <td id="T_98b01_row2_col2" class="data row2 col2" >0.9381</td>
#       <td id="T_98b01_row2_col3" class="data row2 col3" >0.9081</td>
#       <td id="T_98b01_row2_col4" class="data row2 col4" >0.9151</td>
#       <td id="T_98b01_row2_col5" class="data row2 col5" >0.9061</td>
#       <td id="T_98b01_row2_col6" class="data row2 col6" >0.8377</td>
#       <td id="T_98b01_row2_col7" class="data row2 col7" >0.8419</td>
#       <td id="T_98b01_row2_col8" class="data row2 col8" >0.0570</td>
#     </tr>
#     <tr>
#       <th id="T_98b01_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_98b01_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_98b01_row3_col1" class="data row3 col1" >0.9004</td>
#       <td id="T_98b01_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_98b01_row3_col3" class="data row3 col3" >0.9004</td>
#       <td id="T_98b01_row3_col4" class="data row3 col4" >0.9079</td>
#       <td id="T_98b01_row3_col5" class="data row3 col5" >0.8993</td>
#       <td id="T_98b01_row3_col6" class="data row3 col6" >0.8253</td>
#       <td id="T_98b01_row3_col7" class="data row3 col7" >0.8294</td>
#       <td id="T_98b01_row3_col8" class="data row3 col8" >0.5730</td>
#     </tr>
#     <tr>
#       <th id="T_98b01_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_98b01_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_98b01_row4_col1" class="data row4 col1" >0.9004</td>
#       <td id="T_98b01_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_98b01_row4_col3" class="data row4 col3" >0.9004</td>
#       <td id="T_98b01_row4_col4" class="data row4 col4" >0.9100</td>
#       <td id="T_98b01_row4_col5" class="data row4 col5" >0.8982</td>
#       <td id="T_98b01_row4_col6" class="data row4 col6" >0.8273</td>
#       <td id="T_98b01_row4_col7" class="data row4 col7" >0.8343</td>
#       <td id="T_98b01_row4_col8" class="data row4 col8" >0.0210</td>
#     </tr>
#     <tr>
#       <th id="T_98b01_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_98b01_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_98b01_row5_col1" class="data row5 col1" >0.8970</td>
#       <td id="T_98b01_row5_col2" class="data row5 col2" >0.9256</td>
#       <td id="T_98b01_row5_col3" class="data row5 col3" >0.8970</td>
#       <td id="T_98b01_row5_col4" class="data row5 col4" >0.9054</td>
#       <td id="T_98b01_row5_col5" class="data row5 col5" >0.8948</td>
#       <td id="T_98b01_row5_col6" class="data row5 col6" >0.8187</td>
#       <td id="T_98b01_row5_col7" class="data row5 col7" >0.8248</td>
#       <td id="T_98b
