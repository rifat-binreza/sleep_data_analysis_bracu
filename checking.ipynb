# %%
import pandas as pd 
df=pd.read_csv("Sleep_health_and_lifestyle_dataset (1).csv")
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200            NaN
# ...

# %%
! pip install pycaret

# %%
from pycaret.regression import *
clf=setup(
       data=df,target='Sleep Disorder',session_id=12
)
# Out:
# <style type="text/css">
# #T_78d86_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_78d86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_78d86_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_78d86_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_78d86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_78d86_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_78d86_row0_col1" class="data row0 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_78d86_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_78d86_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_78d86_row1_col1" class="data row1 col1" >Quality of Sleep</td>
#     </tr>
#     <tr>
#       <th id="T_78d86_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_3ef1b th {
#   text-align: left;
# }
# ...
