# %%
import pandas as pd 
pd.read_csv('sleep_data_expanded.csv')
# Out:
#       Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0             1    Male   27     Software Engineer             6.1
# 1             2    Male   28                Doctor             6.2
# 2             3    Male   28                Doctor             6.2
# 3             4    Male   28  Sales Representative             5.9
# 4             5    Male   28  Sales Representative             5.9
# ...         ...     ...  ...                   ...             ...
# 2369       2370    Male   39     Software Engineer             6.2
# 2370       2371  Female   40              Engineer             6.7
# 2371       2372  Female   44                 Nurse             6.0
# 2372       2373    Male   46            Accountant             6.8
# 2373       2374  Female   44              Engineer             6.8
#
#       Quality of Sleep  Physical Activity Level  Stress Level   BMI Category  \
# 0                    6                       42             6     Overweight
# ...

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(
    df,
    title="Sleep Health and Lifestyle Dataset - Profiling Report",
    explorative=True
)
profile
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 from ydata_profiling import ProfileReport
#       3 profile = ProfileReport(
# ----> 4     df,
#       5     title="Sleep Health and Lifestyle Dataset - Profiling Report",
#       6     explorative=True
#       7 )
#       8 profile
#
# NameError: name 'df' is not defined
