# %%
import pandas as pd 
df=pd.read_csv('sleep_data_expanded.csv')

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(
    df,
    title="Sleep Health and Lifestyle Dataset - Profiling Report",
    explorative=True
)
profile
# Out:
# ...
# 100%|██████████| 13/13 [00:00<00:00, 112.61it/s]
